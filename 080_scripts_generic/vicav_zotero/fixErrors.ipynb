# %% [markdown]
# # Fix broken biblid fields

# %% [markdown]
# The current Zotero export has several problems (cf. [issue #31](https://github.com/wibarab/featuredb/issues/31):
#
# * duplicate biblIDs
# * ill-formed biblIDs (blanks, leading integers, all sorts of special characters)
# * structural errors in the TEI export
#
# 1. run validation on export
# 2. regenerate IDs for ill-formed or repeated IDs
# 3. update fvo docs in case they referenced repeated IDs
# 4. write new ids to a copy of the Zotero TEI export
# 5. push new ids from TEI export back to Zotero

# %%
import requests
import json
import logging
import os
import re
import xml
import xml.etree.ElementTree as ET
from urllib.parse import urlparse, parse_qs, urlencode
import asyncio
import aiohttp
from random import randrange
# this module is needed to make asyncio.run work inside the notebook as well as in the generated python script
import nest_asyncio
from random import random
nest_asyncio.apply()
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
#logging.basicConfig(level=logging.DEBUG)
import saxonche

from lxml import isoschematron, etree

# %%
xmlns = {"tei": "http://www.tei-c.org/ns/1.0", "xml":"http://www.w3.org/XML/1998/namespace", "": "http://www.tei-c.org/ns/1.0"}
for key in xmlns:
    ET.register_namespace(key, xmlns[key])

# %%
request_headers = {'Authorization': 'Bearer ' + os.environ['API_TOKEN']}
group_id = "2165756"
limit_downloads_to = int(os.environ['LIMIT_DOWNLOADS_TO']) if 'LIMIT_DOWNLOADS_TO' in os.environ and os.environ['LIMIT_DOWNLOADS_TO'] else None
# On GitHub more than one connections to api.zotero.org was broken when this environment variable was introduced
conn_limit=int(os.environ['MAX_CONNECTIONS']) if 'MAX_CONNECTIONS' in os.environ and os.environ['MAX_CONNECTIONS'] else 4 
total_timeout=int(os.environ['TIMEOUT']) if 'TIMEOUT' in os.environ and os.environ['TIMEOUT'] else 5 #s
logging.info("limit_downloads_to = " + str(limit_downloads_to) + ", conn_limit = " + str(conn_limit) + ', total_timeout = ' + str(total_timeout) + 's')
# Out:
# 2023-10-05 01:53:42,661 - limit_downloads_to = None, conn_limit = 4, total_timeout = 5s

# %% [markdown]
# ## Validate current Zotero Export

# %%
# the root of the git repository
dataHome = "../.."
# rng schema
rngSchema = dataHome + "/803_RNG_Schematron/tei_all.rng"

pathToFvoDocuments = dataHome + "/010_manannot/features"

# the path to the Zotero export
pathToZoteroExport=dataHome + "/010_manannot/vicav_biblio_tei_zotero.xml"
pathToFixZoteroXSL=dataHome + "/082_scripts_xsl/fix_zotero_TEI_export.xsl"


with saxonche.PySaxonProcessor(license=False) as proc:
# SaxonC 1.2.1 Python has many known bugs but isn't maintained anymore
# Many of the documented API specs are not working
    print(proc.version)
    proc.set_cwd(os.path.dirname(os.path.abspath('')))
    print(proc.cwd)
# Out:
# SaxonC-HE 12.3 from Saxonica
# /home/dschopper/data/WIBARAB/featuredb/080_scripts_generic

# %%
def getXMLIDs(path):
    ids=[]
    with open(path, "r") as f:
        for index, line in enumerate(f):
            
            pID = re.compile('xml:id=[\'"](.+?)[\'"]')
            matches = pID.search(line)
            if matches:
                ids.append({matches.group(1):index})
    return ids

# %%
def transform(s, xsl, o, parameters=[]):
    # processor keeps files open on Windows and in doing so prevents moving or copying them
    with saxonche.PySaxonProcessor(license=False) as proc:
        proc.set_configuration_property("xi", "on")
        saxon = proc.new_xslt30_processor()
        for i in parameters:
            saxon.set_parameter(name=i, value=proc.make_string_value(parameters[i]))
        exec = saxon.compile_stylesheet(stylesheet_file=os.path.abspath(xsl))
        exec.apply_templates_returning_file(source_file=os.path.abspath(s), output_file=os.path.abspath(o))
        if exec.exception_occurred:
            exec.get_error_message
            #for i in range(saxon.exception_count()-1):
            print(saxon.get_error_message())
            print(os.path.abspath(s)+" - "+os.path.abspath(xsl)+" -> "+os.path.abspath(o)+" failed")
        if os.path.exists(os.path.abspath(o)):
            return o
        else: 
            print("there was an error transforming "+s+" with stylesheet "+xsl)

# %%
def validate(path, rngSchema):
    """Validate a document against the rngSchema. Returns a list of dicts of which each one represents a validation (or parsing) error."""
    validationErrors = []
    
    try:
        doc = etree.parse(path)
    
        # relaxng validation
        relaxng_doc = etree.parse(rngSchema)
        relaxng = etree.RelaxNG(relaxng_doc)
        relaxng.assertValid(doc)
        
    
    except etree.XMLSyntaxError as e:
        valErrObj = {
            "type" : "error",
            "message": str(e), 
            "line": e.lineno,
            "source": path, 
            "location": "n/a",
            "stage" : "parsing", 
            "exceptionType": type(e).__name__
        }
        
        validationErrors.append(valErrObj)     
        return validationErrors
        
    except etree.DocumentInvalid as e:
        for error in e.error_log:
            # we ignore rng errors about @schemaLocation since 
            # that is needed for validation in the TEI-enricher
            if error.message != "Invalid attribute schemaLocation for element TEI":
                location = "n/a" if error.path is None else error.path
                valErrObj = {
                    "type" : "error",
                    "message": error.message, 
                    "line": error.line, 
                    "source": path, 
                    "location": location,
                    "stage" : "relaxng", 
                    "exceptionType": type(e).__name__
                }
                # DEBUG
                print(valErrObj)
                validationErrors.append(valErrObj)        
    
    return validationErrors

# %%
def sanitize(string):
    return re.sub(r'[^a-zA-Z]','', string)

def sanitizeDate(string):
    return re.sub(r'[^0-9]','', string)


def constructID(entry):
    key=entry["key"]
    lastNames=[]
    for c in entry["data"]["creators"]:
        if c["creatorType"] == "author":
            # strip all non-word characters
            if "lastName" in c.keys():
                lastNames.append(sanitize(c["lastName"]))
            else:
                lastNames.append(sanitize(c["name"]))
    date=sanitizeDate(entry["data"]["date"])
    if date == "":
        print(entry)
    ranNum=randrange(1000, 9999,4)
    return "-".join(lastNames)+"_"+date+"_"+str(ranNum)

# %%
def regenerateID(zoteroID, previousAttempts=[]):
    # fetch JSON entry from API
    entryURL=f"https://api.zotero.org/groups/{group_id}/items/{zoteroID}"
    response = requests.get(entryURL)
    if response:
        entry = json.loads(response.text)
        newID=constructID(entry)
        print("regenerating ID for "+zoteroID+": "+newID)
        # check against list of existing IDs 
        # if it does not exists, then return it
        # otherwise try another one
        existingIDs = getXMLIDs(pathToZoteroExport)
        if newID in existingIDs:
            regenerateID(zoteroID, previousAttempts.append(newID))
        else:
            return newID
    else:
         print("an error occured fetching "+entryURL)
         print(e.text)
         print(e.status_code)

# %%
def getByCorresp(ZoteroExport, corresp):
    return ZoteroExport.findall(f".//tei:biblStruct[@corresp='{corresp}']", xmlns)

# %%
def fixZoteroTEIExport(pathToZoteroExport):
    pathToOutput=pathToZoteroExport#+".tmp"
    transform(pathToZoteroExport, pathToFixZoteroXSL, pathToOutput)
    return pathToOutput

# %%
def getFvoByBiblID(biblid):
    biblRefs=[]
    for pathToFvoDoc in os.scandir(pathToFvoDocuments):
        if pathToFvoDoc.name.endswith('.xml') and pathToFvoDoc.is_file():
            filename = os.path.basename(pathToFvoDoc)
            filepath = pathToFvoDocuments + "/" + filename
            parser = etree.XMLParser(recover=True)
            tree=ET.parse(pathToFvoDoc, parser=parser)
            refs=tree.findall(f'.//tei:bibl[@corresp="zot:'+biblid+'"]', xmlns)
            if len(refs) > 0:
                biblRefs.append((filepath,refs))
    return biblRefs

# %% [raw]
# getFvoByBibl("prochazka_2016_3250")

# %%
def getBiblEntryByID(biblid):
    zoteroExport = ET.parse(pathToZoteroExport)
    return zoteroExport.findall('.//biblStruct[@xml:id = "'+biblid+'"]', xmlns)

# %%
def rewriteIDRef(biblRefs, oldID, newID):
    # biblRefs= list of tuples with pos 1= path to document, pos 2= list of elements
    for biblRef in biblRefs:
        filepath=biblRef[0]
        bibls=biblRef[1]
        print(bibls)
        for bibl in bibls:
            bibl.attrib["corresp"] = "zot:"+newID
        dom=bibls[0].getroottree()
        dom.write(filepath, encoding="utf-8", xml_declaration=True)

# %%
def setBiblStatus(biblRefs, status, comment):
    for biblRef in biblRefs:
        filepath=biblRef[0]
        bibls=biblRef[1]
        for bibl in bibls:
            bibl.attrib["status"]=status
            cNode=etree.Comment(comment)
            bibl.insert(0, cNode)
            print(filepath)
        dom=bibls[0].getroottree()
        dom.write(filepath, encoding="utf-8", xml_declaration=True)

# %%
def fixErrors(pathToZoteroExport):
    # fix structural errors in TEI export from Zotero
    vErrs = validate(pathToZoteroExport, rngSchema)
    if len(vErrs) == 0:
        return 
    else:
        vErrsByLine={}
        for i in vErrs:
            vErrsByLine[i["line"]] = i
        
        parser = etree.XMLParser(recover=True)
        ZoteroExport = etree.parse(pathToZoteroExport, parser)
        
        with open(pathToZoteroExport, "r") as f:
            for i, line in enumerate(f):
                if i+1 in vErrsByLine:
                    e = vErrsByLine[i+1]
                    if ("xml:id : attribute value"  in e["message"] and "is not an NCName" in e["message"]) or ("ID" in e["message"] and "already defined" in e["message"]):
                        pCorresp = re.compile('corresp=[\'"](.+?)[\'"]')
                        pID = re.compile('xml:id=[\'"](.+?)[\'"]')
                        corresp = pCorresp.search(line).group(1)
                        oldID = pID.search(line).group(1)
                        if corresp:
                            zoteroKey = corresp.split("/")[-1]
                            bibl = getByCorresp(ZoteroExport, corresp)
                            newID = regenerateID(zoteroKey)
                            
                            # update references to new ID
                            if ("xml:id : attribute value"  in e["message"] and "is not an NCName" in e["message"]):
                                existingReferences = getFvoByBiblID(oldID)
                                if len(existingReferences) > 0:
                                    print("found "+str(len(existingReferences))+" references to ID "+oldID+". Replacing with "+newID+".")
                                    rewriteIDRef(existingReferences, oldID, newID)
                                    setBiblStatus(existingReferences, "CHECKME", "broken ID has been fixed in Zotero export, please revise")
                            else: 
                                # these are ambiguous references which need to be checked again
                                existingReferences = getFvoByBiblID(oldID)

                                # potential targets
                                targets=[]
                                for i in getBiblEntryByID(oldID):
                                    url=i.get("corresp")
                                    id=i.get("{http://www.w3.org/XML/1998/namespace}id")
                                    targets.append((id,url))
                                rewriteIDRef(existingReferences, oldID, newID)
                                targetsString=""
                                for i, t in enumerate(targets):
                                    if i > 1:
                                        targetString=targetString+" or"
                                    targetString+" "+t[0]+" ("+t[1]+")"
                                setBiblStatus(existingReferences, "CHECKME", "ambiguous ID reference. Could be either "+" or ".join(lambda(targets)))

                            bibl[0].attrib["{http://www.w3.org/XML/1998/namespace}id"] = newID
                            
                        else:
                            print("could not identify @corresp in line")
                            print(line)
                    else:
                        print("unhandled error")
                        print(e)
        ZoteroExport.write(pathToZoteroExport, encoding="utf-8", xml_declaration=True)
        vErrsAfterFix = validate(pathToZoteroExport, rngSchema)
        if vErrsAfterFix == vErrs:
            print("fixErrors was not successful, please check messages. Aborting")
            return
        else:
            fixErrors(pathToZoteroExport)

# %%
def flagAmbiguousBiblRefs(pathToZoteroExport):
    zoteroExport=ET.parse(pathToZoteroExport)
    for bibl in zoteroExport.findall(".//tei:biblStruct",xmlns):
        n=bibl.attrib["n"]
        # if id.endswith("a-z"):
        regex=re.compile(r"[a-z]$")
        matches = regex.search(n)
        if matches:
            id=bibl.attrib["{http://www.w3.org/XML/1998/namespace}id"]
            existingReferences = getFvoByBiblID(id)
            if existingReferences:
                setBiblStatus(existingReferences, "CHECKME", "potentially ambiguous references")

# %%
# fix structural errors from Zotero export first 
pathToZoteroExport_fixed=fixZoteroTEIExport(pathToZoteroExport)
fixErrors(pathToZoteroExport_fixed)
flagAmbiguousBiblRefs(pathToZoteroExport_fixed)
# Out:
# regenerating ID for 7CMU89XL: AlNasser_1993_1656
# regenerating ID for WN9XVLC8: Colin_1999_6356
# regenerating ID for 5PAG6FAF: AbuNahleh_1985_6144
# found 27 references to ID abu nahleh_1985_1878. Replacing with AbuNahleh_1985_6144.
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb11f00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb13d40>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb13080>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f07a838d100>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbb8c0>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbb900>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbbd80>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbbf80>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbbe40>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbbf00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbb280>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbb840>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbbec0>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbba380>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbaa00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbaa40>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbab00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbaac0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbba100>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbba800>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbba640>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbb6c0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbac00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbaa80>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbbd40>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbad00>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbba700>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbbae00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbba140>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb44fc0>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb44e00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cbb7180>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f07a8354a00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f07a837aac0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb01e00>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f07a8379f40>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb02ec0>]
# ../../010_manannot/features/feature_bound_pronoun_2ps_sg_f_after_vowel.xml
# ../../010_manannot/features/feature_PFV_3sg_f.xml
# ../../010_manannot/features/feature_bound_pronoun_3ps_sg_m_after_consonant.xml
# ../../010_manannot/features/feature_JAA_3sg_m.xml
# ../../010_manannot/features/features_q.xml
# ../../010_manannot/features/features_q.xml
# ../../010_manannot/features/feature_IPFV_2sg_f.xml
# ../../010_manannot/features/feature_JAA_3sg_f.xml
# ../../010_manannot/features/features_pron_pl_p1_c.xml
# ../../010_manannot/features/features_pron_pl_p1_c.xml
# ../../010_manannot/features/feature_AKL_3sgm_ipfv.xml
# ../../010_manannot/features/features_pron_pl_p3_c.xml
# ../../010_manannot/features/features_pron_pl_p3_c.xml
# ../../010_manannot/features/features_pron_pl_p3_c.xml
# ../../010_manannot/features/feature_raising_a_stressed_closed.xml
# ../../010_manannot/features/feature_raising_a_stressed_open.xml
# ../../010_manannot/features/feature_raising_a_pretonic_closed.xml
# ../../010_manannot/features/features_pron_pl_p2c.xml
# ../../010_manannot/features/feature_bound_pronoun_1ps_pl.xml
# ../../010_manannot/features/feature_raising_a_pretonic_open_i.xml
# ../../010_manannot/features/features_pron_sg_p3_m.xml
# ../../010_manannot/features/features_pron_sg_p3_m.xml
# ../../010_manannot/features/feature_bound_pronoun_2ps_sg_f_after_consonants.xml
# ../../010_manannot/features/feature_bound_pronoun_2ps_pl_c.xml
# ../../010_manannot/features/feature_bound_pronoun_2ps_pl_c.xml
# ../../010_manannot/features/features_pron_sg_p3_f.xml
# ../../010_manannot/features/features_pron_sg_p3_f.xml
# ../../010_manannot/features/feature_IPFV_3pl_m_c.xml
# ../../010_manannot/features/feature_PFV_3pl_m_c.xml
# ../../010_manannot/features/feature_bound_pronoun_3ps_pl_c.xml
# ../../010_manannot/features/feature_bound_pronoun_3ps_pl_c.xml
# ../../010_manannot/features/features_djim.xml
# ../../010_manannot/features/features_djim.xml
# ../../010_manannot/features/feature_AKL_3sgm_pfv.xml
# ../../010_manannot/features/features_k.xml
# ../../010_manannot/features/features_k.xml
# ../../010_manannot/features/feature_bound_pronoun_2ps_sg_m_after_consonant.xml
# regenerating ID for EJHJT3CB: Agius_26291991_3368
# regenerating ID for LYMJRLU5: AitHammou_1988_2960
# regenerating ID for VPW5IBZJ: AitHamza_1995_2500
# regenerating ID for EKVBLT2P: AlGhadi_1990_2568
# regenerating ID for YPRLMWJC: AlGhadi_1994_7412
# regenerating ID for 48XB7LED: AlHuneety_2015_9828
# regenerating ID for R8F3CRX6: AlMashaqba_2015_7660
# regenerating ID for RR5HGR66: AlarcnySantn_1913_1640
# regenerating ID for A9EJMPGP: AlbarracndeMartnezRuiz_1964_2204
# regenerating ID for R5WTIK79: Avram_2016_1432
# regenerating ID for 7TMLL9NZ: Behnstedt_1994_3764
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb8bd00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb8bdc0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb8b640>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb8bd80>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb89ac0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb8bb80>, <Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f078cb8b840>]
# ../../010_manannot/features/feature_IPFV_3sg_m_1w.xml
# ../../010_manannot/features/feature_raising_a_pretonic_closed.xml
# ../../010_manannot/features/feature_raising_a_pretonic_open_i.xml
# ../../010_manannot/features/feature_PFV_3pl_m_c_3wy.xml
# ../../010_manannot/features/feature_PFV_3pl_m_c_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# regenerating ID for BY6ZA2FT: Bassiouney_2009_2960
# regenerating ID for RV222B2U: Ismail_2009_9064
# regenerating ID for R577LKGS: Versteegh_2009_6432
# regenerating ID for K6NYRV2V: Ingham_2009_2604
# regenerating ID for NN3F229T: Eades_2009_2448
# regenerating ID for VY2IINFL: Behnstedt_2009_2312
# regenerating ID for SEXBUVRU: Behnstedt-Woidich_1988_1056
# regenerating ID for MCMLVLRI: Behnstedt-Woidich_1987_9908
# regenerating ID for XR9N7DUQ: Belnap_2009_6160
# regenerating ID for VR25VM4L: BenAjiba_1990_1560
# regenerating ID for BNDKAXBE: BenCheneb_1922_4148
# regenerating ID for TKQVTU87: BenitezCantero_1948_3876
# regenerating ID for Z8VJVGFT: BenhallamAbderraf-Dahbi_1990_1228
# regenerating ID for ZHHJXEY4: Benhallam_1990_8768
# regenerating ID for EBCWQ2PB: BentezFernndez_2006_6572
xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# regenerating ID for LCYWGFF2: CastilloyOlivas_1860_7088
# regenerating ID for Z7PGZ2CW: CaussindePerceval_2018_2232
# regenerating ID for JSFJCUSX: Hagge_2003_6036
# regenerating ID for WDZT9SHV: Doss_2003_6192
# regenerating ID for GCNQ7NMH: Blau_2003_5136
# regenerating ID for 5AX6G2WQ: Chetrit_2003_5176
# regenerating ID for 8FIF6CWV: DAnna_2017_2756
# regenerating ID for CJ8DXN79: DAnna_2018_4828
# regenerating ID for MPDJF6H3: DAnna_2018_5332
# regenerating ID for G5HMUCTE: DAnna_2019715_9644
# regenerating ID for 9EULE83I: DAnna_2020_1940
# regenerating ID for 4237UF4S: DAnna_2020_4480
# regenerating ID for IIS2SV4G: DAnna_2020_2956
# regenerating ID for 4FZ9RCVG: DAnna_2020_9472
# regenerating ID for 97WAQLM7: DAnna_2021_2768
# regenerating ID for DY7HI2JZ: deAlcala_1883_2960
# regenerating ID for WWURN579: DeJong_1996_4180
# regenerating ID for L7HN6K7L: DeJong_1996_6556
# regenerating ID for N2NCTC8C: DeJong_2015_8796
# regenerating ID for HHGKSCQ8: DeSimone_1979_2312
# regenerating ID for SI97G9YJ: DeSimone_1994_2640
# regenerating ID for MW9B4GIQ: Eades_2009_3752
# regenerating ID for UQ4Z4NF6: ElAwd_1990_1860
# regenerating ID for RTV583LQ: ElAyadi_1984_3460
# regenerating ID for FQFBTG86: ElBakkioui_2002_6912
# regenerating ID for HGTQPNIF: ElHadri_1993_3176
# regenerating ID for ZJDIUR9G: ElHakimi_1995_2252
# regenerating ID for 6C3XJKSQ: ElHaloui_2001_4348
# regenerating ID for W3KFRILB: ElHassani_1997_4276
# regenerating ID for NWE8S4DX: ElZarka_2009_6436
# regenerating ID for 38CV4YU4: Elimam_2003_2044
# regenerating ID for BGSUMRVK: Ennaji_1990_5300
# regenerating ID for HK5IP32R: Ferguson_1997_1540
# regenerating ID for 2W65RP7Z: GmezRovira-MoscosoGarca-RuzRoman_20002001_1700
# regenerating ID for L95PBPIJ: GmezBarcel_2001_3024
# regenerating ID for SIH4MNE5: GmezFont_1996_7812
# regenerating ID for DKG777QV: GrandHenry_1969_4664
# regenerating ID for L3PLIX94: GrandHenry_1971_5232
# regenerating ID for AVBNUMUL: GrandHenry_1972_8932
# regenerating ID for I7LRHYKS: GrandHenry_1975_3812
# regenerating ID for VRGPCHPW: GrandHenry_1976_8328
# regenerating ID for YFVNNVL7: GrandHenry_1976_2228
# regenerating ID for JZEYAHP3: GrandHenry_1976_1540
# regenerating ID for DTCMI6CY: GrandHenry_1977_3060
# regenerating ID for Y6AV4UWV: GrandHenry_1977_1656
# regenerating ID for MYLKQRRC: GrandHenry_1977_8544
# regenerating ID for P3F48VZM: GrandHenry_1978_9940
# regenerating ID for XP3EXGA8: GrandHenry_1980_3824
# regenerating ID for SPTRXA63: GrandHenry_1981_6888
# regenerating ID for KWIJTF4Q: GrandHenry_1989_4916
# regenerating ID for UEXBQGCC: GrandHenry_1990_7604
# regenerating ID for NB6A3KYG: GrandHenry_1991_4732
# regenerating ID for G9FFJ5CC: GrandHenry_1993_1660
# regenerating ID for GPRBE5ZW: GrandHenry_1995_1152
# regenerating ID for DQX5ADIU: GrandHenry_1998_8588
# regenerating ID for QWZ38V2S: GrandHenry_2001_4240
# regenerating ID for YW6SSFFZ: GrandHenry_2005_5120
# regenerating ID for E9XITWZC: GrandHenry_1979_9004
# found 33 references to ID grand`henry_1979_0000. Replacing with GrandHenry_1979_9004.
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816b540>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816ae80>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816b1c0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778169480>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816a980>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778168380>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816b900>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778169400>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816b180>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816bfc0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816b440>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816bb80>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f07781699c0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778168d00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778168400>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778168580>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778169f40>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816b600>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816aa40>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778169cc0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816ab00>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778169080>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816abc0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816b740>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778169340>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778169500>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816a600>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f0778169740>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816a680>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816a440>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816be40>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816afc0>]
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f077816a780>]
# ../../010_manannot/features/feature_bound_pronoun_2ps_sg_f_after_vowel.xml
# ../../010_manannot/features/feature_gahawa2.xml
# ../../010_manannot/features/feature_bound_pronoun_3ps_sg_m_after_vowel.xml
# ../../010_manannot/features/feature_PFV_3sg_f.xml
# ../../010_manannot/features/feature_IPFV_3sg_m_1w.xml
# ../../010_manannot/features/feature_bound_pronoun_3ps_sg_m_after_consonant.xml
# ../../010_manannot/features/feature_JAA_3sg_m.xml
# ../../010_manannot/features/features_q.xml
# ../../010_manannot/features/feature_IPFV_2sg_f.xml
# ../../010_manannot/features/feature_JAA_3sg_f.xml
# ../../010_manannot/features/feature_apophonic_passive.xml
# ../../010_manannot/features/feature_raising_a_stressed_closed.xml
# ../../010_manannot/features/feature_raising_a_stressed_open.xml
# ../../010_manannot/features/feature_raising_a_pretonic_closed.xml
# ../../010_manannot/features/feature_gahawa1_maGCuuC.xml
# ../../010_manannot/features/feature_t_form_passive.xml
# ../../010_manannot/features/feature_raising_a_pretonic_open_i.xml
# ../../010_manannot/features/feature_bound_pronoun_3ps_sg_f_after_vowel.xml
# ../../010_manannot/features/feature_JAA_3pl_mc.xml
# ../../010_manannot/features/feature_traditional_classification.xml
# ../../010_manannot/features/feature_IPFV_3pl_m_c.xml
# ../../010_manannot/features/feature_PFV_3pl_m_c.xml
# ../../010_manannot/features/features_interdentals.xml
# ../../010_manannot/features/feature_PFV_3pl_m_c_3wy.xml
# ../../010_manannot/features/features_template.xml
# ../../010_manannot/features/features_djim.xml
# ../../010_manannot/features/features_ghayn.xml
# ../../010_manannot/features/feature_bound_pronoun_2ps_sg_m_after_vowel.xml
# ../../010_manannot/features/feature_gahawa1_aGCaC.xml
# ../../010_manannot/features/feature_gahawa1_yaGCvC.xml
# ../../010_manannot/features/features_k.xml
# ../../010_manannot/features/feature_gahawa1_CaGCvC.xml
# ../../010_manannot/features/feature_PFV_3sg_f_3wy.xml
# regenerating ID for BSA2EA5A: GuerreroParrado_2015_9632
# regenerating ID for JDBQV5ZA: GuerreroParrado_2019_9296
# regenerating ID for JYZWL6Y3: Gussenhoven_82006_2676
# regenerating ID for I3I3VQ5H: Dalman_19641971_5244
# regenerating ID for DU26M4IH: HerreroMuosCobo_1994_2016
# regenerating ID for E9GPRW8Y: HerreroMuozCobo_1996_8816
# regenerating ID for MQEXENCG: HerreroMuozCobo_1998_9784
# regenerating ID for 4EBFZRVT: HerreroMuozCobo_2003_1012
# regenerating ID for REK878DJ: Hilili_2004_3468
# regenerating ID for 6A8L3GIW: Hilili_2005_3652
# regenerating ID for 2JZ9YIRU: Holes_2001_2740
# regenerating ID for N3DHG7H6: Holes_2018_6324
# regenerating ID for ZSTSY7NG: Holes_2018_4648
# regenerating ID for 6UF7LNUU: IbnAbdalall_1980_4268
# regenerating ID for IG8P5QXY: Prochzka_2016_8548
# regenerating ID for LZTVJUZ4: Prochzka_2004_1744
# regenerating ID for UXYIKEM3: RoSnchez_2013_4236
# regenerating ID for UU4AZ6RZ: RomeoBiedma_1998_1104
# regenerating ID for 3ZLSAGKT: Ryding_2006_1188
# regenerating ID for 9ULCHQXL: Said_1955_9560
# regenerating ID for EI5X6928: Sad_2002_1700
# regenerating ID for 7KSEVHBX: Sab_1990_1028
# regenerating ID for 7AFS9LWU: SnchezSandoval_2004_7156
# regenerating ID for I3DMAAJ7: Seeger_2002_3848
# regenerating ID for DJVFBMPN: Levin_2002_2568
# regenerating ID for S9PUMFQZ: Fischer_2002_5856
# regenerating ID for B49VIVGD: Singer_197374_1704
# regenerating ID for 5AM697EL: Socin_1882_5644
# regenerating ID for ECVI4T4L: StatisticalCenterofIran_2016_9644
# regenerating ID for J9D82XQ9: Talay_2013_5564
# regenerating ID for EX5HKLMG: ThayThayRhozali_2000_4180
# regenerating ID for SM5WN5WE: ThayThayRhozali_2000_8680
# regenerating ID for 8B6JHU3Q: VanWagoner_1944_8964
# regenerating ID for SN98GBJ3: Versteegh_2014_7248
# regenerating ID for BEE5L3IM: Vicente_2008_9864
# regenerating ID for 8B4UEU69: Huehnergard-Rubin_2011_9128
# regenerating ID for 4RML9GMK: Zafrani_2003_1796
# regenerating ID for WXCZXF7U: Zawrotna_2016_5828
# regenerating ID for K3XW3F5F: Ziamari_2007_7196
# [<Element {http://www.tei-c.org/ns/1.0}bibl at 0x7f07714c47c0>]
# ../../010_manannot/features/features_q.xml
# regenerating ID for 5FKIN5MQ: Zubi_2014_1956
# regenerating ID for T4QDS6YY: Zubi_20190401_9432
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 # fix structural errors from Zotero export first
#       2 pathToZoteroExport_fixed=fixZoteroTEIExport(pathToZoteroExport)
# ----> 3 fixErrors(pathToZoteroExport_fixed)
#       4 flagAmbiguousBiblRefs(pathToZoteroExport_fixed)
#
# Cell In[16], line 61, in fixErrors(pathToZoteroExport)
#      59     return
#      60 else:
# ---> 61     fixErrors(pathToZoteroExport)
#
# Cell In[16], line 61, in fixErrors(pathToZoteroExport)
#      59     return
#      60 else:
# ---> 61     fixErrors(pathToZoteroExport)
#
#     [... skipping similar frames: fixErrors at line 61 (186 times)]
#
# Cell In[16], line 61, in fixErrors(pathToZoteroExport)
#      59     return
#      60 else:
# ---> 61     fixErrors(pathToZoteroExport)
#
# Cell In[16], line 56, in fixErrors(pathToZoteroExport)
#      54                 print(e)
#      55 ZoteroExport.write(pathToZoteroExport, encoding="utf-8", xml_declaration=True)
# ---> 56 vErrsAfterFix = validate(pathToZoteroExport, rngSchema)
#      57 if vErrsAfterFix == vErrs:
#      58     print("fixErrors was not successful, please check messages. Aborting")
#
# Cell In[7], line 11, in validate(path, rngSchema)
#       9     relaxng_doc = etree.parse(rngSchema)
#      10     relaxng = etree.RelaxNG(relaxng_doc)
# ---> 11     relaxng.assertValid(doc)
#      14 except etree.XMLSyntaxError as e:
#      15     valErrObj = {
#      16         "type" : "error",
#      17         "message": str(e),
#    (...)
#      22         "exceptionType": type(e).__name__
#      23     }
#
# KeyboardInterrupt:
